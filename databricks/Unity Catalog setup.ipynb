# %%
# %sql
CREATE CATALOG IF NOT EXISTS nexforge;
CREATE SCHEMA IF NOT EXISTS nexforge.bronze;
CREATE SCHEMA IF NOT EXISTS nexforge.silver;
CREATE SCHEMA IF NOT EXISTS nexforge.gold;
CREATE SCHEMA IF NOT EXISTS nexforge.sandbox;
